# %%
# !pip install xlsxwriter
# Out:
# Requirement already satisfied: xlsxwriter in c:\users\my_pc\appdata\local\programs\python\python310\lib\site-packages (3.2.9)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install html5lib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: html5lib in c:\users\testing rename nalng\appdata\roaming\python\python312\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\programdata\anaconda3\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from html5lib) (0.5.1)

# %%
import pandas as pd
import numpy as np
import os
from io import BytesIO
import warnings
warnings.filterwarnings("ignore", "This pattern is interpreted as a regular expression")

# ================================
# CONFIGURATION
# ================================
SIGNED_HTML_PATH = r'C:/Users/Testing Rename nalng/Documents/Sports Interactive/Football Manager 2024/Frosinone Signings Available S4 Summer.html' #Transfers
LOANS_HTML_PATH = r'C:/Users/Testing Rename nalng/Documents/Sports Interactive/Football Manager 2024/Frosinone Loans Available S4 Summer.html' #Loans
UNIVERSAL_HTML_PATH = r'C:/Users/Testing Rename nalng/Documents/Sports Interactive/Football Manager 2024/Frosinone Universe S4 Summer.html'
OUTPUT_PATH = r'C:/Users/Testing Rename nalng/Desktop/Frosinone_Season_4_Summer_fixes_FB.xlsx'
LEAGUE_MULTIPLIERS_PATH = r'C:/Users/Testing Rename nalng/Desktop/League Multipliers.xlsx'  # Path to your Excel file

TEXT_COLUMNS = [
    'UID', 'Name', 'Rec', 'EU National', 'Position', 'Pros',
    'Preferred Foot', 'Inf', 'Transfer Value', 'Nat', 'Division', 'Club', 'Personality'
]

PERCENTAGE_COLUMNS = ['Sv %', 'OP-Cr %', 'Hdr %', 'Conv %', 'Pas %', 'Cr C/A', 'Tck R', 'Pens Saved Ratio', 'Pen/R', 'Shot %']

# ================================
# LOAD LEAGUE POWER RATINGS FROM EXCEL
# ================================
def load_league_power(file_path):
    try:
        # Read the Excel file
        df = pd.read_excel(file_path)
        
        # Convert to dictionary with 'League' as key and 'Power Rating' as value
        league_power = dict(zip(df['League'], df['Power Rating']))
        
        # Add default 'Others' value if not present in the file
        if 'Others' not in league_power:
            league_power['Others'] = 5
            
        return league_power
    except Exception as e:
        print(f"Error loading league power ratings: {e}")
        # Return a default dictionary if file can't be loaded
        return {'Others': 5}

# Load the league power ratings
LEAGUE_POWER = load_league_power(LEAGUE_MULTIPLIERS_PATH)

# ================================
# LEAGUE NAME FIXES FOR ENCODING ISSUES
# ================================
LEAGUE_NAME_FIXES = {
    'BrasileirÃ£o AssaÃ­ SÃ©rie A': 'Brasileirão Assaí Série A',
    'Primera FederaciÃ³n Grupo I': 'Primera Federación Grupo I',
    'Liga Profesional de FÃºtbol': 'Liga Profesional de Fútbol',
    'Primera FederaciÃ³n Grupo I': 'Primera Federación Grupo',
    'Primera FederaciÃ³n Grupo III': 'Primera Federación Grupo',
    'Primera FederaciÃ³n Grupo IV': 'Primera Federación Grupo',
    'Primera FederaciÃ³n Grupo V': 'Primera Federación Grupo',
    'Primera FederaciÃ³n Grupo VI': 'Primera Federación Grupo',
    'Primera FederaciÃ³n Grupo VII': 'Primera Federación Grupo',
    'Regionalliga SÃ¼dwest': 'Regionalliga Südwest',
    'Serie C NOW Girone A': 'Serie C NOW',
    'Serie C NOW Girone B': 'Serie C NOW',
    'Serie C NOW Girone C': 'Serie C NOW',
    'Spor Toto SÃ¼per Lig': 'Spor Toto Süper Lig',
    'French National 3 - Group A': 'French National 3',
    'French National 3 - Group B': 'French National 3',
    'French National 3 - Group C': 'French National 3',
    'French National 3 - Group D': 'French National 3',
    'French National 3 - Group E': 'French National 3',
    'French National 3 - Group F': 'French National 3',
    'French National 3 - Group G': 'French National 3',
    'French National 3 - Group H': 'French National 3',
    'French National 3 - Group I': 'French National 3',
    'French National 3 - Group J': 'French National 3',
    'French National 3 - Group K': 'French National 3',
    'French National 3 - Group L': 'French National 3',
    'BrasileirÃ£o Serie B Chevrolet': 'Brasileirão Serie B Chevrolet',
    'Serie D Girone A': 'Serie D',
    'Serie D Girone B': 'Serie D',
    'Serie D Girone C': 'Serie D',
    'Serie D Girone D': 'Serie D',
    'Serie D Girone E': 'Serie D',
    'Serie D Girone F': 'Serie D',
    'Serie D Girone G': 'Serie D',
    'Serie D Girone H': 'Serie D',
    'Serie D Girone I': 'Serie D',
    'Serie D Girone J': 'Serie D',
    'Serie D Girone K': 'Serie D',
    'Regionalliga West': 'Regionalliga',
    'Regionalliga Nord': 'Regionalliga',
    'Regionalliga Südwest': 'Regionalliga',
    'Regionalliga Bayern': 'Regionalliga',
    'Regionalliga Nordost': 'Regionalliga',
    'Russian Second Division A Gold': 'Russian Second Division A',
    'Russian Second Division A Silver': 'Russian Second Division A',  
    'Russian Second Division A Bronze': 'Russian Second Division A',    
    'Russian Second Division B - Group 1': 'Russian Second Division B',
    'Russian Second Division B - Group 2': 'Russian Second Division B',
    'Russian Second Division B - Group 3': 'Russian Second Division B',
    'DR Congo Premier Division A': 'DR Congolese Premier Division',
    'DR Congo Premier Division B': 'DR Congolese Premier Division',

    # Add more fixes as needed
}

def fix_league_names(df):
    """Fix encoding issues in league names in the DataFrame"""
    if 'Division' in df.columns:
        df['Division'] = df['Division'].replace(LEAGUE_NAME_FIXES)
    return df

# ================================
# LOAD HTML FILES
# ================================
if not os.path.exists(SIGNED_HTML_PATH):
    raise FileNotFoundError(f"Signed players HTML not found: {SIGNED_HTML_PATH}")

if not os.path.exists(UNIVERSAL_HTML_PATH):
    raise FileNotFoundError(f"Universal players HTML not found: {UNIVERSAL_HTML_PATH}")

if not os.path.exists(LOANS_HTML_PATH):
    raise FileNotFoundError(f"Loan players HTML not found: {LOANS_HTML_PATH}")

with open(SIGNED_HTML_PATH, 'r', encoding='utf-8') as file:
    signed_tables = pd.read_html(file)
df_signed = signed_tables[0].copy()
df_signed = fix_league_names(df_signed)

with open(UNIVERSAL_HTML_PATH, 'r', encoding='utf-8') as file:
    universal_tables = pd.read_html(file)
df_universal = universal_tables[0].copy()
df_universal = fix_league_names(df_universal)

with open(LOANS_HTML_PATH, 'r', encoding='utf-8') as file:
    loans_tables = pd.read_html(file)
df_loans = loans_tables[0].copy()
df_loans = fix_league_names(df_loans)

# %%
# ================================
# UID‑BASED MERGE AND LABEL  ✅ Fixed version
# ================================

def normalize_uid(df):
    df = df.copy()
    # Convert to float → Int64 (nullable integer) → string
    df['UID'] = pd.to_numeric(df['UID'], errors='coerce')  # force numeric, NaNs stay if bad
    df['UID'] = df['UID'].astype('Int64')                  # keep NaNs clean
    df['UID'] = df['UID'].astype(str).str.strip()          # final string
    return df

# 1️⃣ Normalize UIDs
df_signed    = normalize_uid(df_signed)
df_universal = normalize_uid(df_universal)
df_loans = normalize_uid(df_loans)

# 2️⃣ Add the signability flags
df_signed['Signability']    = 'Available for Transfer'
df_universal['Signability'] = 'Not Transferrable'
df_loans['Signability'] = 'Available on Loan'


# 3️⃣ Concatenate signables first, drop duplicate UIDs

df = (
    pd.concat([df_signed, df_loans, df_universal], ignore_index=True)
      .drop_duplicates(subset='UID', keep='first')
      .reset_index(drop=True)
)

# ================================
# CLEANING & CONVERSION
# ================================
def clean_and_convert_data(df):
    def convert_percentage_to_float(df, column):
        if column in df.columns:
            df[column] = (df[column].astype(str)
                          .str.replace('%', '')
                          .replace('-', np.nan)
                          .astype(float))
        return df

    # Convert minutes
    if 'Mins' in df.columns:
        df['Mins'] = pd.to_numeric(df['Mins'], errors='coerce')
        df = df[df['Mins'] >= 900].copy()

    # Convert percentage stats
    for col in PERCENTAGE_COLUMNS:
        df = convert_percentage_to_float(df, col)

    # Handle 'Dist/90' - e.g., "7.3mi"
    if 'Dist/90' in df.columns:
        df['Dist/90'] = (
            df['Dist/90']
            .astype(str)
            .str.extract(r'([\d.]+)')[0]
        )

        # Drop only if the string was completely missing
        df['Dist/90'] = pd.to_numeric(df['Dist/90'], errors='coerce')

    print("Dist/90 (after cleaning):")
    print(df['Dist/90'].describe())
    print(df['Dist/90'].dropna().head(10))






    

    # Convert all other numerical columns (except text & signability)
    for col in df.columns:
        if col not in TEXT_COLUMNS + ['Signability']:
            df[col] = pd.to_numeric(df[col], errors='coerce')

    # Handle 'Dist/90' - e.g., "7.3mi"
    if 'Dist/90' in df.columns:
        df['Dist/90'] = (
            df['Dist/90']
            .astype(str)
            .str.extract(r'([\d.]+)')[0]
        )

        # Drop only if the string was completely missing
        df['Dist/90'] = pd.to_numeric(df['Dist/90'], errors='coerce')

    print("Dist/90 (after cleaning):")
    print(df['Dist/90'].describe())
    print(df['Dist/90'].dropna().head(10))


    # Add league strength multiplier
    def get_league_multiplier(division):
        return LEAGUE_POWER.get(division, LEAGUE_POWER['Others']) / 100.0

    df['League Multiplier'] = df['Division'].apply(get_league_multiplier)
    return df

# ✅ Apply cleaning
df = clean_and_convert_data(df)

# ================================
# CONVERT RAW STATS TO PER 90
# ================================
RAW_STATS_TO_PER90 = {
    "Yel": "Yellow/90",
    "Red": "Red/90",
    "Fls": "FoulsMade/90",
    "FA": "FoulsAgainst/90",
    "Off": "Offsides/90",
    "Gl Mst": "Gl Mst/90",
    "Goals Outside Box": "Goals Outside Box/90",
    "FK Shots": "FKShots/90"
}

for raw_stat, per90_stat in RAW_STATS_TO_PER90.items():
    if raw_stat in df.columns:
        df[raw_stat] = pd.to_numeric(df[raw_stat], errors='coerce')
        df['Mins'] = pd.to_numeric(df['Mins'], errors='coerce')
        df[per90_stat] = (df[raw_stat] / (df['Mins'] / 90)).fillna(0)
    else:
        print(f"Warning: Raw stat '{raw_stat}' not found in DataFrame")

print(df['Dist/90'].dropna().unique()[:50])
print(df['Dist/90'].dtype)
# Out:
# Dist/90 (after cleaning):
# count    21113.000000
# mean         4.777227
# std          3.292260
# min          0.000000
# 25%          0.100000
# 50%          6.800000
# 75%          7.500000
# max          9.300000
# Name: Dist/90, dtype: float64
# 0    6.3
# 1    7.0
# 2    6.4
# 3    7.4
# 4    7.7
# 5    6.7
# 6    7.8
# 7    6.5
# 8    6.3
# 9    6.3
# Name: Dist/90, dtype: float64
# Dist/90 (after cleaning):
# count    21113.000000
# mean         4.777227
# std          3.292260
# min          0.000000
# 25%          0.100000
# 50%          6.800000
# 75%          7.500000
# max          9.300000
# Name: Dist/90, dtype: float64
# 0    6.3
# 1    7.0
# 2    6.4
# 3    7.4
# 4    7.7
# 5    6.7
# 6    7.8
# 7    6.5
# 8    6.3
# 9    6.3
# Name: Dist/90, dtype: float64
# [6.3 7.  6.4 7.4 7.7 6.7 7.8 6.5 6.6 8.  7.2 6.8 6.9 6.2 7.6 7.1 7.5 7.9
#  7.3 4.8 5.1 6.  6.1 4.9 5.7 5.3 5.8 8.1 8.2 4.7 5.5 3.7 4.3 5.4 5.6 5.
#  5.9 4.5 3.3 4.1 8.3 5.2 2.3 1.9 8.6 2.2 4.  3.8 2.6 3.4]
# float64

# %%
df["Expires"] = df["Expires"].astype("string")
print(df["Expires"].dtype)
# Out:
# string

# %%
# Show overall info
print("==== DataFrame Info ====")
print(df.info())

print("\n==== Column Summary ====")
for col in df.columns:
    print(f"\n📌 Column: {col}")
    print(f"Type: {df[col].dtype}")
    print(f"Missing: {df[col].isna().sum()} / {len(df)}")
    
    if df[col].dtype == 'object':
        unique_vals = df[col].dropna().unique()
        print(f"Unique Values: {len(unique_vals)}")
        print("Sample:", unique_vals[:10])
    
    elif pd.api.types.is_numeric_dtype(df[col]):
        print(df[col].describe())

    else:
        print("Sample:", df[col].dropna().head(5).tolist())
# Out:
# ==== DataFrame Info ====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21113 entries, 0 to 21112
# Data columns (total 88 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EU National           21113 non-null  object
#  1   Name                  21113 non-null  object
#  2   UID                   21113 non-null  object
#  3   Mins                  21113 non-null  int64
#  4   Position              21113 non-null  object
#  5   Shot %                19162 non-null  float64
#  6   Personality           1825 non-null   object
#  7   Age                   21113 non-null  int64
#  8   Preferred Foot        21113 non-null  object
#  9   Rec                   21113 non-null  object
#  10  Club                  21113 non-null  object
#  11  Transfer Value        21113 non-null  object
#  12  Sv %                  1935 non-null   float64
#  13  OP-Cr %               14291 non-null  float64
#  14  Off                   21113 non-null  int64
#  15  Hdr %                 14663 non-null  float64
#  16  Distance              0 non-null      float64
#  17  Cr C/A                12002 non-null  float64
#  18  Conv %                14947 non-null  float64
#  19  Saves/90              1265 non-null   float64
#  20  Clr/90                21113 non-null  float64
#  21  FA                    21113 non-null  int64
#  22  Tck/90                20262 non-null  float64
#  23  Shot/90               19162 non-null  float64
#  24  xGP                   1935 non-null   float64
#  25  ShT/90                19162 non-null  float64
#  26  Shots Outside Box/90  19178 non-null  float64
#  27  Shts Blckd/90         19178 non-null  float64
#  28  Pr passes/90          21113 non-null  float64
#  29  Pres C/90             21113 non-null  float64
#  30  Pres A/90             21113 non-null  float64
#  31  Poss Won/90           21113 non-null  float64
#  32  Poss Lost/90          21113 non-null  float64
#  33  Ps C/90               21113 non-null  float64
#  34  Ps A/90               21113 non-null  float64
#  35  OP-KP/90              21113 non-null  float64
#  36  OP-Crs C/90           19178 non-null  float64
#  37  OP-Crs A/90           19178 non-null  float64
#  38  NP-xG/90              21113 non-null  float64
#  39  Gl Mst                21113 non-null  int64
#  40  K Tck/90              21113 non-null  float64
#  41  K Ps/90               14893 non-null  float64
#  42  K Hdrs/90             21113 non-null  float64
#  43  Int/90                14620 non-null  float64
#  44  Sprints/90            21113 non-null  float64
#  45  Hdrs W/90             14663 non-null  float64
#  46  Gls/90                14947 non-null  float64
#  47  All/90                1935 non-null   float64
#  48  xA/90                 21113 non-null  float64
#  49  xG/90                 21113 non-null  float64
#  50  xGP/90                1935 non-null   float64
#  51  Drb/90                14008 non-null  float64
#  52  Dist/90               21113 non-null  float64
#  53  Cr C/90               19178 non-null  float64
#  54  Cln/90                1935 non-null   float64
#  55  Ch C/90               12920 non-null  float64
#  56  Cons                  0 non-null      float64
#  57  Pas A                 21113 non-null  int64
#  58  Inf                   8308 non-null   object
#  59  Pas %                 21113 non-null  float64
#  60  Blk/90                14033 non-null  float64
#  61  Aer A/90              14663 non-null  float64
#  62  Asts/90               16353 non-null  float64
#  63  Crs A/90              19178 non-null  float64
#  64  Hdrs L/90             14641 non-null  float64
#  65  Division              21113 non-null  object
#  66  Nat                   21113 non-null  object
#  67  Fls                   21113 non-null  int64
#  68  xG/shot               21113 non-null  float64
#  69  FK Shots              19178 non-null  float64
#  70  Goals Outside Box     19178 non-null  float64
#  71  Tck R                 20262 non-null  float64
#  72  xG-OP                 21113 non-null  float64
#  73  Pens Saved Ratio      1084 non-null   float64
#  74  Pen/R                 1813 non-null   float64
#  75  Yel                   21113 non-null  int64
#  76  Red                   21113 non-null  int64
#  77  Expires               0 non-null      string
#  78  Signability           21113 non-null  object
#  79  League Multiplier     21113 non-null  float64
#  80  Yellow/90             21113 non-null  float64
#  81  Red/90                21113 non-null  float64
#  82  FoulsMade/90          21113 non-null  float64
#  83  FoulsAgainst/90       21113 non-null  float64
#  84  Offsides/90           21113 non-null  float64
#  85  Gl Mst/90             21113 non-null  float64
#  86  Goals Outside Box/90  21113 non-null  float64
#  87  FKShots/90            21113 non-null  float64
# dtypes: float64(65), int64(9), object(13), string(1)
# memory usage: 14.2+ MB
# None
#
# ==== Column Summary ====
#
# 📌 Column: EU National
# Type: object
# Missing: 0 / 21113
# Unique Values: 2
# Sample: ['No' 'Yes']
#
# 📌 Column: Name
# Type: object
# Missing: 0 / 21113
# Unique Values: 20620
# Sample: ['Aleksandar MarkoviÄ\x87' 'Dominic Kristkowitz' 'Antonio Obama'
#  'Fernando GonzÃ¡lez GonzÃ¡lez' 'Francesco Porcelli' 'Joan Cabrero'
#  'Johann Lejeune' 'Azimjon Sheraliev' 'Eloi' 'Ylber Tahiri']
#
# 📌 Column: UID
# Type: object
# Missing: 0 / 21113
# Unique Values: 21113
# Sample: ['2002109057' '2002118201' '2002098162' '2002106622' '2002106366'
#  '2002126448' '2002118177' '2002115754' '2002098548' '2002097859']
#
# 📌 Column: Mins
# Type: int64
# Missing: 0 / 21113
# count    21113.000000
# mean      2658.924975
# std        880.710701
# min       1000.000000
# 25%       1950.000000
# 50%       2716.000000
# 75%       3465.000000
# max       5160.000000
# Name: Mins, dtype: float64
#
# 📌 Column: Position
# Type: object
# Missing: 0 / 21113
# Unique Values: 557
# Sample: ['D (C)' 'D (C), DM' 'D (LC)' 'D (RC)' 'D (RC), DM' 'D (R)' 'D/WB (R)'
#  'D (C), WB (R)' 'D (RL)' 'D/WB/M/AM (R)']
#
# 📌 Column: Shot %
# Type: float64
# Missing: 1951 / 21113
# count    19162.000000
# mean        30.456476
# std         15.616303
# min          0.000000
# 25%         19.000000
# 50%         31.000000
# 75%         42.000000
# max        100.000000
# Name: Shot %, dtype: float64
#
# 📌 Column: Personality
# Type: object
# Missing: 19288 / 21113
# Unique Values: 27
# Sample: ['Fairly Determined' 'Fairly Ambitious' 'Resolute' 'Light-Hearted'
#  'Driven' 'Mercenary' 'Fairly Professional' 'Spirited' 'Low Determination'
#  'Professional']
#
# 📌 Column: Age
# Type: int64
# Missing: 0 / 21113
# count    21113.000000
# mean        25.761142
# std          4.388424
# min         16.000000
# 25%         22.000000
# 50%         25.000000
# 75%         29.000000
# max         39.000000
# Name: Age, dtype: float64
#
# 📌 Column: Preferred Foot
# Type: object
# Missing: 0 / 21113
# Unique Values: 6
# Sample: ['Unknown' 'Right' 'Left' 'Right Only' 'Left Only' 'Either']
#
# 📌 Column: Rec
# Type: object
# Missing: 0 / 21113
# Unique Values: 1
# Sample: ['- - -']
#
# 📌 Column: Club
# Type: object
# Missing: 0 / 21113
# Unique Values: 3197
# Sample: ['Bulls FC Academy' 'JFG Saarlouis/Dillin. U19' 'Inter de Madrid'
#  'F.C. Andorra B' 'Luciano Manara' '26 de Febrero' 'Vannes OC'
#  'ConstÃ\xa0ncia' 'Sabadell B' 'Casertana']
#
# 📌 Column: Transfer Value
# Type: object
# Missing: 0 / 21113
# Unique Values: 1586
# Sample: ['Unknown' '$0' '$0 - $70K' '$0 - $35K' '$85K - $850K' '$0 - $16K'
#  '$1.5K - $14K' '$3K - $10K' '$16K - $150K' '$0 - $2.5K']
#
# 📌 Column: Sv %
# Type: float64
# Missing: 19178 / 21113
# count    1935.000000
# mean       46.044961
# std        34.003111
# min         0.000000
# 25%         0.000000
# 50%        66.000000
# 75%        72.000000
# max       100.000000
# Name: Sv %, dtype: float64
#
# 📌 Column: OP-Cr %
# Type: float64
# Missing: 6822 / 21113
# count    14291.000000
# mean        15.624029
# std         12.873332
# min          0.000000
# 25%          9.000000
# 50%         14.000000
# 75%         20.000000
# max        100.000000
# Name: OP-Cr %, dtype: float64
#
# 📌 Column: Off
# Type: int64
# Missing: 0 / 21113
# count    21113.000000
# mean         3.016625
# std          5.147480
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          4.000000
# max         57.000000
# Name: Off, dtype: float64
#
# 📌 Column: Hdr %
# Type: float64
# Missing: 6450 / 21113
# count    14663.000000
# mean        43.843074
# std         19.764639
# min          0.000000
# 25%         26.000000
# 50%         43.000000
# 75%         62.000000
# max        100.000000
# Name: Hdr %, dtype: float64
#
# 📌 Column: Distance
# Type: float64
# Missing: 21113 / 21113
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Distance, dtype: float64
#
# 📌 Column: Cr C/A
# Type: float64
# Missing: 9111 / 21113
# count    12002.000000
# mean        18.666556
# std         12.486852
# min          1.000000
# 25%         11.000000
# 50%         16.000000
# 75%         22.000000
# max        100.000000
# Name: Cr C/A, dtype: float64
#
# 📌 Column: Conv %
# Type: float64
# Missing: 6166 / 21113
# count    14947.000000
# mean        12.278986
# std          8.464679
# min          1.000000
# 25%          7.000000
# 50%         11.000000
# 75%         16.000000
# max        100.000000
# Name: Conv %, dtype: float64
#
# 📌 Column: Saves/90
# Type: float64
# Missing: 19848 / 21113
# count    1265.000000
# mean        2.033202
# std         1.021372
# min         0.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max         5.000000
# Name: Saves/90, dtype: float64
#
# 📌 Column: Clr/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         1.080925
# std          1.683606
# min          0.000000
# 25%          0.000000
# 50%          0.780000
# 75%          1.270000
# max         11.140000
# Name: Clr/90, dtype: float64
#
# 📌 Column: FA
# Type: int64
# Missing: 0 / 21113
# count    21113.000000
# mean        27.646190
# std         19.958475
# min          0.000000
# 25%         13.000000
# 50%         23.000000
# 75%         38.000000
# max        160.000000
# Name: FA, dtype: float64
#
# 📌 Column: Tck/90
# Type: float64
# Missing: 851 / 21113
# count    20262.000000
# mean         1.532264
# std          0.668508
# min          0.000000
# 25%          1.070000
# 50%          1.580000
# 75%          1.970000
# max          4.960000
# Name: Tck/90, dtype: float64
#
# 📌 Column: Shot/90
# Type: float64
# Missing: 1951 / 21113
# count    19162.000000
# mean         1.234999
# std          0.974730
# min          0.020000
# 25%          0.450000
# 50%          0.910000
# 75%          1.840000
# max          6.830000
# Name: Shot/90, dtype: float64
#
# 📌 Column: xGP
# Type: float64
# Missing: 19178 / 21113
# count    1935.000000
# mean        1.224362
# std         5.304511
# min       -29.590000
# 25%         0.000000
# 50%         0.000000
# 75%         3.645000
# max        21.970000
# Name: xGP, dtype: float64
#
# 📌 Column: ShT/90
# Type: float64
# Missing: 1951 / 21113
# count    19162.000000
# mean         0.457224
# std          0.496192
# min          0.000000
# 25%          0.090000
# 50%          0.250000
# 75%          0.690000
# max          3.320000
# Name: ShT/90, dtype: float64
#
# 📌 Column: Shots Outside Box/90
# Type: float64
# Missing: 1935 / 21113
# count    19178.000000
# mean         0.256625
# std          0.305814
# min          0.000000
# 25%          0.000000
# 50%          0.160000
# 75%          0.390000
# max          2.480000
# Name: Shots Outside Box/90, dtype: float64
#
# 📌 Column: Shts Blckd/90
# Type: float64
# Missing: 1935 / 21113
# count    19178.000000
# mean         0.196236
# std          0.353165
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.270000
# max          3.020000
# Name: Shts Blckd/90, dtype: float64
#
# 📌 Column: Pr passes/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         2.075625
# std          1.940616
# min          0.000000
# 25%          0.000000
# 50%          1.920000
# 75%          3.690000
# max          9.100000
# Name: Pr passes/90, dtype: float64
#
# 📌 Column: Pres C/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         1.337767
# std          1.149765
# min          0.000000
# 25%          0.000000
# 50%          1.340000
# 75%          2.340000
# max          4.850000
# Name: Pres C/90, dtype: float64
#
# 📌 Column: Pres A/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         4.910946
# std          4.284432
# min          0.000000
# 25%          0.000000
# 50%          4.790000
# 75%          8.950000
# max         17.200000
# Name: Pres A/90, dtype: float64
#
# 📌 Column: Poss Won/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         6.324495
# std          6.168320
# min          0.000000
# 25%          0.030000
# 50%          4.280000
# 75%         11.750000
# max         35.750000
# Name: Poss Won/90, dtype: float64
#
# 📌 Column: Poss Lost/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         8.196182
# std          7.188911
# min          0.000000
# 25%          0.170000
# 50%          7.000000
# 75%         14.320000
# max         38.090000
# Name: Poss Lost/90, dtype: float64
#
# 📌 Column: Ps C/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean        27.454109
# std         13.107006
# min          6.950000
# 25%         14.440000
# 50%         25.590000
# 75%         39.300000
# max         73.470000
# Name: Ps C/90, dtype: float64
#
# 📌 Column: Ps A/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean        33.815520
# std         12.952598
# min         14.880000
# 25%         21.430000
# 50%         30.620000
# 75%         45.880000
# max         78.040000
# Name: Ps A/90, dtype: float64
#
# 📌 Column: OP-KP/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.578199
# std          0.547692
# min          0.000000
# 25%          0.000000
# 50%          0.480000
# 75%          1.030000
# max          2.670000
# Name: OP-KP/90, dtype: float64
#
# 📌 Column: OP-Crs C/90
# Type: float64
# Missing: 1935 / 21113
# count    19178.000000
# mean         0.178430
# std          0.256621
# min          0.000000
# 25%          0.000000
# 50%          0.070000
# 75%          0.250000
# max          1.870000
# Name: OP-Crs C/90, dtype: float64
#
# 📌 Column: OP-Crs A/90
# Type: float64
# Missing: 1935 / 21113
# count    19178.000000
# mean         1.165111
# std          1.581490
# min          0.000000
# 25%          0.000000
# 50%          0.500000
# 75%          1.680000
# max          9.590000
# Name: OP-Crs A/90, dtype: float64
#
# 📌 Column: NP-xG/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.125765
# std          0.116385
# min          0.000000
# 25%          0.040000
# 50%          0.090000
# 75%          0.190000
# max          0.890000
# Name: NP-xG/90, dtype: float64
#
# 📌 Column: Gl Mst
# Type: int64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.077772
# std          0.349192
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          6.000000
# Name: Gl Mst, dtype: float64
#
# 📌 Column: K Tck/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.059331
# std          0.093340
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.090000
# max          0.810000
# Name: K Tck/90, dtype: float64
#
# 📌 Column: K Ps/90
# Type: float64
# Missing: 6220 / 21113
# count    14893.000000
# mean         0.897735
# std          0.578788
# min          0.020000
# 25%          0.420000
# 50%          0.870000
# 75%          1.260000
# max          5.400000
# Name: K Ps/90, dtype: float64
#
# 📌 Column: K Hdrs/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.193845
# std          0.303621
# min          0.000000
# 25%          0.000000
# 50%          0.040000
# 75%          0.270000
# max          1.830000
# Name: K Hdrs/90, dtype: float64
#
# 📌 Column: Int/90
# Type: float64
# Missing: 6493 / 21113
# count    14620.000000
# mean         1.408291
# std          0.608178
# min          0.020000
# 25%          1.050000
# 50%          1.430000
# 75%          1.780000
# max          3.930000
# Name: Int/90, dtype: float64
#
# 📌 Column: Sprints/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         5.827862
# std          5.162632
# min          0.000000
# 25%          0.000000
# 50%          5.440000
# 75%         10.020000
# max         27.110000
# Name: Sprints/90, dtype: float64
#
# 📌 Column: Hdrs W/90
# Type: float64
# Missing: 6450 / 21113
# count    14663.000000
# mean         2.568529
# std          1.749132
# min          0.000000
# 25%          1.210000
# 50%          2.110000
# 75%          3.730000
# max          8.770000
# Name: Hdrs W/90, dtype: float64
#
# 📌 Column: Gls/90
# Type: float64
# Missing: 6166 / 21113
# count    14947.000000
# mean         0.159243
# std          0.154885
# min          0.020000
# 25%          0.050000
# 50%          0.100000
# 75%          0.220000
# max          1.090000
# Name: Gls/90, dtype: float64
#
# 📌 Column: All/90
# Type: float64
# Missing: 19178 / 21113
# count    1935.000000
# mean        1.243535
# std         0.353481
# min         0.000000
# 25%         1.020000
# 50%         1.230000
# 75%         1.460000
# max         3.410000
# Name: All/90, dtype: float64
#
# 📌 Column: xA/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.089584
# std          0.076892
# min          0.000000
# 25%          0.030000
# 50%          0.080000
# 75%          0.120000
# max          0.790000
# Name: xA/90, dtype: float64
#
# 📌 Column: xG/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.127064
# std          0.118416
# min          0.000000
# 25%          0.040000
# 50%          0.090000
# 75%          0.190000
# max          0.890000
# Name: xG/90, dtype: float64
#
# 📌 Column: xGP/90
# Type: float64
# Missing: 19178 / 21113
# count    1935.000000
# mean        0.038207
# std         0.179673
# min        -1.430000
# 25%         0.000000
# 50%         0.000000
# 75%         0.130000
# max         0.780000
# Name: xGP/90, dtype: float64
#
# 📌 Column: Drb/90
# Type: float64
# Missing: 7105 / 21113
# count    14008.000000
# mean         1.004458
# std          0.841351
# min          0.020000
# 25%          0.360000
# 50%          0.810000
# 75%          1.372500
# max          5.080000
# Name: Drb/90, dtype: float64
#
# 📌 Column: Dist/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         4.777227
# std          3.292260
# min          0.000000
# 25%          0.100000
# 50%          6.800000
# 75%          7.500000
# max          9.300000
# Name: Dist/90, dtype: float64
#
# 📌 Column: Cr C/90
# Type: float64
# Missing: 1935 / 21113
# count    19178.000000
# mean         0.224691
# std          0.335338
# min          0.000000
# 25%          0.000000
# 50%          0.080000
# 75%          0.320000
# max          3.640000
# Name: Cr C/90, dtype: float64
#
# 📌 Column: Cln/90
# Type: float64
# Missing: 19178 / 21113
# count    1935.000000
# mean        0.303876
# std         0.137136
# min         0.000000
# 25%         0.210000
# 50%         0.300000
# 75%         0.380000
# max         0.930000
# Name: Cln/90, dtype: float64
#
# 📌 Column: Ch C/90
# Type: float64
# Missing: 8193 / 21113
# count    12920.000000
# mean         0.203827
# std          0.154621
# min          0.020000
# 25%          0.090000
# 50%          0.160000
# 75%          0.280000
# max          1.340000
# Name: Ch C/90, dtype: float64
#
# 📌 Column: Cons
# Type: float64
# Missing: 21113 / 21113
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Cons, dtype: float64
#
# 📌 Column: Pas A
# Type: int64
# Missing: 0 / 21113
# count    21113.000000
# mean       981.576375
# std        490.835250
# min        225.000000
# 25%        639.000000
# 50%        842.000000
# 75%       1255.000000
# max       3483.000000
# Name: Pas A, dtype: float64
#
# 📌 Column: Inf
# Type: object
# Missing: 12805 / 21113
# Unique Values: 22
# Sample: ['Loa' 'Ctr' 'Inj' 'Yth' 'Ama' 'Wnt' 'Unh' 'Ask' 'Opt' 'Rst']
#
# 📌 Column: Pas %
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean        78.150002
# std         10.974634
# min         35.000000
# 25%         69.000000
# 50%         83.000000
# 75%         86.000000
# max         96.000000
# Name: Pas %, dtype: float64
#
# 📌 Column: Blk/90
# Type: float64
# Missing: 7080 / 21113
# count    14033.000000
# mean         0.391228
# std          0.220407
# min          0.020000
# 25%          0.220000
# 50%          0.370000
# 75%          0.530000
# max          1.420000
# Name: Blk/90, dtype: float64
#
# 📌 Column: Aer A/90
# Type: float64
# Missing: 6450 / 21113
# count    14663.000000
# mean         5.734747
# std          2.664999
# min          0.020000
# 25%          4.010000
# 50%          5.560000
# 75%          7.410000
# max         15.930000
# Name: Aer A/90, dtype: float64
#
# 📌 Column: Asts/90
# Type: float64
# Missing: 4760 / 21113
# count    16353.000000
# mean         0.128205
# std          0.088999
# min          0.020000
# 25%          0.060000
# 50%          0.110000
# 75%          0.170000
# max          0.920000
# Name: Asts/90, dtype: float64
#
# 📌 Column: Crs A/90
# Type: float64
# Missing: 1935 / 21113
# count    19178.000000
# mean         1.524023
# std          2.202456
# min          0.000000
# 25%          0.000000
# 50%          0.560000
# 75%          2.370000
# max         23.320000
# Name: Crs A/90, dtype: float64
#
# 📌 Column: Hdrs L/90
# Type: float64
# Missing: 6472 / 21113
# count    14641.000000
# mean         3.171050
# std          1.980611
# min          0.020000
# 25%          2.000000
# 50%          2.620000
# 75%          3.910000
# max         11.040000
# Name: Hdrs L/90, dtype: float64
#
# 📌 Column: Division
# Type: object
# Missing: 0 / 21113
# Unique Values: 557
# Sample: ['National Premier Leagues - NSW' 'German U19 Lower Division' '-'
#  'Spanish Regional Division' 'Italian Promozione Lombardia Grp.B'
#  'Spanish U19 Division 1 Group 4' 'French National 3'
#  'Tercera FederaciÃ³n Grupo XI' 'Spanish Superlliga Catalana' 'Serie D']
#
# 📌 Column: Nat
# Type: object
# Missing: 0 / 21113
# Unique Values: 177
# Sample: ['AUS' 'GER' 'EQG' 'AND' 'ITA' 'ESP' 'FRA' 'TJK' 'ALB' 'MAD']
#
# 📌 Column: Fls
# Type: int64
# Missing: 0 / 21113
# count    21113.000000
# mean        28.974329
# std         16.766312
# min          0.000000
# 25%         17.000000
# 50%         28.000000
# 75%         40.000000
# max         96.000000
# Name: Fls, dtype: float64
#
# 📌 Column: xG/shot
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.102022
# std          0.046847
# min          0.000000
# 25%          0.090000
# 50%          0.110000
# 75%          0.130000
# max          1.000000
# Name: xG/shot, dtype: float64
#
# 📌 Column: FK Shots
# Type: float64
# Missing: 1935 / 21113
# count    19178.000000
# mean         0.152623
# std          0.807945
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         29.000000
# Name: FK Shots, dtype: float64
#
# 📌 Column: Goals Outside Box
# Type: float64
# Missing: 1935 / 21113
# count    19178.000000
# mean         0.333611
# std          0.776659
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         11.000000
# Name: Goals Outside Box, dtype: float64
#
# 📌 Column: Tck R
# Type: float64
# Missing: 851 / 21113
# count    20262.000000
# mean        77.485638
# std         18.008300
# min          0.000000
# 25%         74.000000
# 50%         81.000000
# 75%         87.000000
# max        100.000000
# Name: Tck R, dtype: float64
#
# 📌 Column: xG-OP
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean        -0.448621
# std          2.775714
# min        -13.710000
# 25%         -1.590000
# 50%         -0.310000
# 75%          0.570000
# max         19.380000
# Name: xG-OP, dtype: float64
#
# 📌 Column: Pens Saved Ratio
# Type: float64
# Missing: 20029 / 21113
# count    1084.000000
# mean       21.226937
# std        28.370621
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        33.000000
# max       100.000000
# Name: Pens Saved Ratio, dtype: float64
#
# 📌 Column: Pen/R
# Type: float64
# Missing: 19300 / 21113
# count    1813.000000
# mean       81.782129
# std        32.731995
# min         0.000000
# 25%        75.000000
# 50%       100.000000
# 75%       100.000000
# max       100.000000
# Name: Pen/R, dtype: float64
#
# 📌 Column: Yel
# Type: int64
# Missing: 0 / 21113
# count    21113.000000
# mean         2.398143
# std          3.059821
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          4.000000
# max         22.000000
# Name: Yel, dtype: float64
#
# 📌 Column: Red
# Type: int64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.285227
# std          0.683896
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          9.000000
# Name: Red, dtype: float64
#
# 📌 Column: Expires
# Type: string
# Missing: 21113 / 21113
# Sample: []
#
# 📌 Column: Signability
# Type: object
# Missing: 0 / 21113
# Unique Values: 3
# Sample: ['Available for Transfer' 'Available on Loan' 'Not Transferrable']
#
# 📌 Column: League Multiplier
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.319718
# std          0.247956
# min          0.050000
# 25%          0.050000
# 50%          0.300000
# 75%          0.500000
# max          0.800000
# Name: League Multiplier, dtype: float64
#
# 📌 Column: Yellow/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.085783
# std          0.103679
# min          0.000000
# 25%          0.000000
# 50%          0.049972
# 75%          0.139607
# max          0.734536
# Name: Yellow/90, dtype: float64
#
# 📌 Column: Red/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.009688
# std          0.023720
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.297619
# Name: Red/90, dtype: float64
#
# 📌 Column: FoulsMade/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.996354
# std          0.471493
# min          0.000000
# 25%          0.731311
# 50%          1.025446
# 75%          1.309457
# max          3.884365
# Name: FoulsMade/90, dtype: float64
#
# 📌 Column: FoulsAgainst/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.953109
# std          0.629660
# min          0.000000
# 25%          0.477997
# 50%          0.847212
# 75%          1.253027
# max          6.576728
# Name: FoulsAgainst/90, dtype: float64
#
# 📌 Column: Offsides/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.113988
# std          0.186712
# min          0.000000
# 25%          0.000000
# 50%          0.029871
# 75%          0.136986
# max          1.642699
# Name: Offsides/90, dtype: float64
#
# 📌 Column: Gl Mst/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.002710
# std          0.012585
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.212934
# Name: Gl Mst/90, dtype: float64
#
# 📌 Column: Goals Outside Box/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.011826
# std          0.030294
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.439024
# Name: Goals Outside Box/90, dtype: float64
#
# 📌 Column: FKShots/90
# Type: float64
# Missing: 0 / 21113
# count    21113.000000
# mean         0.005632
# std          0.030832
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.986945
# Name: FKShots/90, dtype: float64

# %%
if df['Dist/90'].isna().any():
    print("⚠️ Warning: Missing or zero values found in Dist/90")

# %%
# ================================
# DATA PREPROCESSING
# ================================

#############################################################
# 1. Intensity: Burst capacity for high-tempo pressing
df['Intensity_Score'] = df['Sprints/90'] / (df['Dist/90'] + 0.1)

# 2. Possession Quality: Efficiency of ball retention
df['Poss_Quality'] = df['Poss Won/90'] / (df['Poss Lost/90'] + 0.1)

# 3. Proactivity: Stopping play cleanly before a foul
df['Proactivity_Index'] = (df['Int/90'] + df['K Tck/90']) / (df['FoulsMade/90'] + 1)

# 4. Creativity: Danger-weighted playmaking
df['Creativity_Index'] = (df['xA/90'] * 0.7) + (df['Ch C/90'] * 0.3)

# 5. Finishing Index: Clinical nature relative to xG
df['Finishing_Index'] = df['Gls/90'] / (df['NP-xG/90'] + 0.01)
#############################################################

# Define numeric columns to scale (excluding text columns and Signability)
TEXT_COLUMNS = ['EU National', 'Name', 'UID', 'Position', 'Personality', 'Preferred Foot', 
                'Rec', 'Club', 'Transfer Value', 'Division', 'Nat', 'Inf', 'Signability','Expires']
                
numeric_columns = [col for col in df.columns 
                   if col not in TEXT_COLUMNS 
                   and pd.api.types.is_numeric_dtype(df[col])]

# Scale numeric columns (0-1)
for col in numeric_columns:
    if col == 'Age':
        continue  # Skip scaling for Age column
    if df[col].nunique() > 1:  # Only scale if there's variation
        min_val = df[col].min()
        max_val = df[col].max()
        df[col] = (df[col] - min_val) / (max_val - min_val)
    else:
        df[col] = 0.5  # Default value for constant columns

# Add league multiplier (no scaling needed)
def get_league_multiplier(division):
    return LEAGUE_POWER.get(division, LEAGUE_POWER['Others']) / 100.0

df['League Multiplier'] = df['Division'].apply(get_league_multiplier)

# ================================
# UPDATED ARCHETYPE FORMULAS (SCALED)
# ================================
ARCHETYPE_FORMULAS = {
    "Sweeper Keeper": {
        "filter": df['Position'].str.contains("GK", case=False, na=False),
        "formula": lambda d: (
            0.70 * ((d["xGP/90"] * 0.7) + (d["Sv %"] * 0.3)) +  # Vital Two: Shot Stopping
            0.20 * d["Ps %"] +                                 # System Fit: Short Passing
            0.10 * (1 - d["Gl Mst/90"])                        # System Fit: Low Concession
        ),
        "label": "SK Rating"
    },
    
    "Central Defender (Stopper)": {
        "filter": df['Position'].str.contains(r"^D\s*\(([RLC]*C[RLC]*)\)", regex=True, na=False),
        "formula": lambda d: (
            0.70 * ((d["Hdrs W/90"] * 0.6) + (d["Tck/90"] * 0.4)) + # Vital Two: Duel Dominance
            0.20 * d["Proactivity_Index"] +                         # System Fit: High Line Defense
            0.10 * (1 - d["Gl Mst/90"])                             # System Fit: Clean Sheet Proxy
        ),
        "label": "CD Rating"
    },
    
    "Complete Wingback (Support)": {
        "filter": df['Position'].str.contains(r"^(D|WB)\s*\((R|L|RL|RLC)\)", regex=True, na=False),
        "formula": lambda d: (
            0.70 * ((d["OP-Crs C/90"] * 0.6) + (d["Intensity_Score"] * 0.4)) + # Vital Two: Low Crossing/Engine
            0.20 * d["xA/90"] +                                               # System Fit: Chance Quality
            0.10 * d["Poss_Quality"]                                          # System Fit: Ball Security
        ),
        "label": "CWB Rating"
    },
    
    "Defensive Midfielder (Defend)": {
        "filter": df['Position'].str.contains(r"DM", regex=True, na=False),
        "formula": lambda d: (
            0.70 * ((d["Int/90"] * 0.6) + (d["Ps %"] * 0.4)) + # Vital Two: Intercept & Retain
            0.20 * d["Proactivity_Index"] +                    # System Fit: Tactical Fouling Avoidance
            0.10 * d["Tck R"]                                  # System Fit: Duel Success Rate
        ),
        "label": "DM Rating"
    },
    
    "Inside Forward (Attack)": {
        "filter": df['Position'].str.contains(r"^AM\s*\((L|R|RL|RLC)\)", regex=True, na=False),
        "formula": lambda d: (
            0.70 * ((d["NP-xG/90"] * 0.5) + (d["Drb/90"] * 0.5)) + # Vital Two: Scoring Threat/Progression
            0.20 * d["Intensity_Score"] +                          # System Fit: High-Tempo Pressing
            0.10 * d["Creativity_Index"]                           # System Fit: Link-up Play
        ),
        "label": "IF Rating"
    },
    
    "Attacking Midfielder (Support)": {
        "filter": df['Position'].str.contains(r"^AM\s*\((C|RLC)\)", regex=True, na=False),
        "formula": lambda d: (
            0.70 * ((d["xA/90"] * 0.6) + (d["Ch C/90"] * 0.4)) + # Vital Two: Killer Pass Volume
            0.20 * d["Pr passes/90"] +                           # System Fit: Vertical Progression
            0.10 * d["Ps %"]                                     # System Fit: Short Passing Control
        ),
        "label": "AM Rating"
    },
    
    "Striker (Advanced Forward)": {
        "filter": df['Position'].str.contains(r"ST", regex=True, na=False),
        "formula": lambda d: (
            0.70 * ((d["NP-xG/90"] * 0.6) + (d["Intensity_Score"] * 0.4)) + # Vital Two: Finding Space/Pace
            0.20 * d["xG/shot"] +                                          # System Fit: Quality Through Balls
            0.10 * (1 - d["Offsides/90"])                                  # System Fit: Timing of Runs
        ),
        "label": "ST Rating"
    }
}



# ================================
# OUTPUT TO EXCEL WITH SUMMARY SHEET
# ================================
output_excel = BytesIO()

with pd.ExcelWriter(output_excel, engine='xlsxwriter', engine_kwargs={'options': {'strings_to_urls': False}}) as writer:
    workbook = writer.book
    unicode_format = workbook.add_format({'font_name': 'Arial Unicode MS', 'valign': 'vcenter'})
    
    # First create the summary sheet at the beginning
    worksheet = workbook.add_worksheet('Player Archetype Summary')
    writer.sheets['Player Archetype Summary'] = worksheet
    
    # Dictionary to store archetype data for summary
    summary_data = []
    
    # Process all archetypes
    for role, config in ARCHETYPE_FORMULAS.items():
        role_df = df[config["filter"]].copy()
        if role_df.empty:
            continue

        # Calculate ratings
        role_df[config["label"]] = config["formula"](role_df)
        adjusted_label = f"Adjusted {config['label']}"
        role_df[adjusted_label] = role_df[config["label"]] * role_df['League Multiplier']
        
        # Calculate percentile for each player within this archetype
        role_df['Percentile'] = role_df[adjusted_label].rank(pct=True)
        
        # Store data for summary
        top_players = role_df[role_df['Percentile'] > 0.95][['UID', 'Name', 'Percentile']].copy()
        top_players['Archetype'] = role
        summary_data.append(top_players)
        
        # Write archetype sheet
        role_df['Ranking'] = role_df[adjusted_label].rank(method='min', ascending=False)
        
        output_cols = [
            'UID', 'Name', 'Age', 'Personality', 'Signability', 'EU National', 'Position', 'Preferred Foot',
            'Transfer Value', 'Nat', 'Division', 'Club',
            config["label"], adjusted_label, 'Percentile', 'Ranking', 'League Multiplier', 'Expires'
        ]
        
        result_df = role_df[output_cols].copy().sort_values(by=adjusted_label, ascending=False)
        result_df.to_excel(writer, sheet_name=role, index=False)
        
        # Format archetype sheet
        archetype_sheet = writer.sheets[role]
        for i, col in enumerate(output_cols):
            archetype_sheet.set_column(i, i, 20 if col != 'Name' else 30, unicode_format)
        
        # Format percentile as percentage
        percent_format = workbook.add_format({'num_format': '0.0%'})
        percentile_col_idx = output_cols.index('Percentile')
        archetype_sheet.set_column(percentile_col_idx, percentile_col_idx, 12, percent_format)
    
    # ================================
    # BUILD SUMMARY SHEET DATA
    # ================================
    if summary_data:
        all_archetypes = pd.concat(summary_data).sort_values(['UID', 'Percentile'], ascending=[True, False])
        
        # Group and format archetypes
        def format_archetypes(group):
            return ", ".join(f"{row['Archetype']} ({row['Percentile']:.1%})" for _, row in group.iterrows())
        
        player_summary = (
            all_archetypes.groupby(['UID', 'Name'])
            .apply(format_archetypes)
            .reset_index(name='Top Archetypes (>95%)')
        )
        
        # Add additional info
        player_summary = player_summary.merge(
            df[['UID', 'Position', 'Age', 'Nat', 'Club', 'Division', 'Personality', 'Signability', 'Transfer Value']],
            on='UID', how='left'
        )
        
        # Final columns and sorting
        player_summary = player_summary[[
            'UID', 'Name', 'Position', 'Club', 'Division', 
            'Signability', 'Transfer Value', 'Age', 'Nat', 'Personality', 'Top Archetypes (>95%)'
        ]]
        player_summary['Archetype Count'] = player_summary['Top Archetypes (>95%)'].str.count(',') + 1
        player_summary = player_summary.sort_values(['Archetype Count', 'Name'], ascending=[False, True])
        
        # Write to summary sheet
        player_summary.to_excel(writer, sheet_name='Player Archetype Summary', index=False)
        
        # Format summary sheet
        summary_sheet = writer.sheets['Player Archetype Summary']
        summary_sheet.set_column('A:A', 15)  # UID
        summary_sheet.set_column('B:B', 30)  # Name
        summary_sheet.set_column('C:C', 15)  # Position
        summary_sheet.set_column('D:D', 25)  # Club
        summary_sheet.set_column('E:E', 25)  # Division
        summary_sheet.set_column('F:F', 15)  # Signability
        summary_sheet.set_column('G:G', 15)  # Transfer Value
        summary_sheet.set_column('H:H', 60)  # Age
        summary_sheet.set_column('I:I', 60)  # Nationality
        summary_sheet.set_column('J:J', 60)  # Personality
        summary_sheet.set_column('K:K', 60)  # Top Archetypes

# ================================
# SAVE FILE
# ================================
try:
    with open(OUTPUT_PATH, 'wb') as output_file:
        output_file.write(output_excel.getbuffer())
    print(f"\n✅ Success! Output file saved:\n{OUTPUT_PATH}")
    print(f"Includes {len(ARCHETYPE_FORMULAS)} archetype sheets + summary sheet")
except Exception as e:
    print(f"\n❌ Error saving file: {e}")
    print("Please check directory permissions or disk space.")
# Out:
# C:\Users\Testing Rename nalng\AppData\Local\Temp\ipykernel_12664\2981730019.py:193: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(format_archetypes)
# ✅ Success! Output file saved:
# C:/Users/Testing Rename nalng/Desktop/Frosinone_Season_4_Summer_fixes_FB.xlsx
# Includes 7 archetype sheets + summary sheet

# %%
# Test each archetype with dummy perfect player
test_player = {col: 1 for col in numeric_columns}
for name, archetype in ARCHETYPE_FORMULAS.items():
    print(f"{name}: {archetype['formula'](test_player)}")
# Out:
# Sweeper Keeper: 0.9
# Central Defender: 0.9
# Fullback: 1.0
# Defensive Midfielder: 1.0
# Winger: 1.0
# Attacking Midfielder: 1.0
# Striker: 1.0
